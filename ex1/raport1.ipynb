# %%
import pandas
import matplotlib as plt

# %%
df = pandas.read_csv('./single_node.txt', sep=';').drop(columns=['b'])
df
# Out:
#          type   size           cap
# 0   buffered       1  1.105390e+06
# 1   buffered       2  1.989691e+06
# 2   buffered       4  3.946768e+06
# 3   buffered       8  8.014434e+06
# 4   buffered      16  1.583443e+07
# 5   buffered      32  3.201213e+07
# 6   buffered      64  6.249459e+07
# 7   buffered     128  1.192332e+08
# 8   buffered     256  2.226303e+08
# 9   buffered     512  4.110396e+08
# 10  buffered    1024  7.663036e+08
# 11  buffered    2048  1.392843e+09
# 12  buffered    4096  2.550557e+09
# 13  buffered    8192  3.965699e+09
# 14  buffered   16384  5.592714e+09
# 15  buffered   24576  6.189610e+09
# 16  buffered   28000  6.434851e+09
# 17  buffered   32768  6.754545e+09
# 18  buffered   40960  8.071635e+09
# 19  buffered   49152  8.451432e+09
# 20  buffered   57344  8.776414e+09
# 21  buffered   65536  8.884476e+09
# 22  buffered   73728  9.506065e+09
# 23      sync       1  1.379041e+06
# 24      sync       2  2.574899e+06
# 25      sync       4  4.977110e+06
# 26      sync       8  1.010317e+07
# 27      sync      16  2.045568e+07
# 28      sync      32  4.020752e+07
# 29      sync      64  7.844894e+07
# 30      sync     128  1.474501e+08
# 31      sync     256  2.763560e+08
# 32      sync     512  5.276072e+08
# 33      sync    1024  9.626965e+08
# 34      sync    2048  1.825696e+09
# 35      sync    4096  3.100230e+09
# 36      sync    8192  4.929901e+09
# 37      sync   16384  6.662207e+09
# 38      sync   24576  7.746365e+09
# 39      sync   28000  7.985794e+09
# 40      sync   32768  8.162488e+09
# 41      sync   40960  9.787949e+09
# 42      sync   49152  1.021044e+10
# 43      sync   57344  1.044397e+10
# 44      sync   65536  1.151002e+10
# 45      sync   73728  1.216187e+10

# %%
df = df.pivot(index="size", columns="type", values='cap')

# %%
df.plot(title='Single node throughput')
# Out:
# <AxesSubplot:title={'center':'Single node throughput'}, xlabel='size'>

# %%
df = pandas.read_csv('./two_nodes.txt', sep=';').drop(columns=['b'])
df = df.pivot(index="size", columns="type", values='cap')
df.plot(title="Two nodes throughput)
# Out:
# <AxesSubplot:title={'center':'Two nodes throughput'}, xlabel='size'>

# %% [markdown]
# sync ; 1 ; 3500 ; 1379041.01643
# sync ; 2 ; 3500 ; 2574899.27044
# sync ; 4 ; 3500 ; 4977110.09753
# sync ; 8 ; 3500 ; 10103170.0881
# sync ; 16 ; 3500 ; 20455676.2447
# sync ; 32 ; 3500 ; 40207520.0899
# sync ; 64 ; 3500 ; 78448938.1902
# sync ; 128 ; 3500 ; 147450053.811
# sync ; 256 ; 3500 ; 276356016.84
# sync ; 512 ; 3500 ; 527607166.527
# sync ; 1024 ; 3500 ; 962696501.637
# sync ; 2048 ; 3500 ; 1825696491.03
# sync ; 4096 ; 3500 ; 3100230000.05
# sync ; 8192 ; 3500 ; 4929901149.65
# sync ; 16384 ; 3500 ; 6662207117.39
# sync ; 24576 ; 3500 ; 7746364698.23
# sync ; 32768 ; 3500 ; 8454539296.94
# sync ; 28000 ; 3500 ; 7985793959.29
# sync ; 32768 ; 1000 ; 8162488049.83
# sync ; 40960 ; 1000 ; 9787948957.0
# sync ; 49152 ; 1000 ; 10210443680.9
# sync ; 57344 ; 1000 ; 10443972907.5
# sync ; 65536 ; 1000 ; 11510016883.0
# sync ; 73728 ; 1000 ; 12161872248.5
